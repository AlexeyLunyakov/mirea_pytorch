# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexeyLunyakov/mirea_pytorch/blob/main/3d_dz_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import gc
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# * float32 - вещественные числа одинарной точности: 1 бит знака, 8 бит экспоненты, 23 бита мантисы (числа размером 4 байта).
#
# * float64 - вещественные числа двойной точности: 1 бит знака, 11 бит экспоненты, 52 бита мантисы (числа размером 8 байт).
#
# * float16 - вещественные числа половинной точности: 1 бит знака, 5 бит экспоненты, 10 бит мантисы (числа размером 2 байта).
#
# * int32 - целые числа в диапазоне от -2147483648 по 2147483647, (числа размером 4 байта).
#
# * int64 - целые числа в диапазоне от -9223372036854775808 по 9223372036854775807, (числа размером 8 байт).

# %%
# пример через torch.full()

size = abs(int(input("Введите размер тензора (матрица квадратная): ")))

a = torch.torch.full((size, size), 5,dtype= torch.float32, device='cuda')
print(a)
#61645 - аналогично с int32
torch.cuda.empty_cache()
# Out:
# Введите размер тензора (матрица квадратная): 0
# tensor([], device='cuda:0', size=(0, 0))

# %% [markdown]
# *float32*
# ![изображение.png](data:image/png;base64,...)![изображение.png]()

# %%
# пример через torch.full()

size = abs(int(input("Введите размер тензора (матрица квадратная): ")))

a = torch.torch.full((size, size), 5,dtype= torch.int64, device='cuda')
print(a)
#43645 - аналогично с float64
torch.cuda.empty_cache()
# Out:
# Введите размер тензора (матрица квадратная): 0
# tensor([], device='cuda:0', size=(0, 0), dtype=torch.int64)

# %%
# пример через torch.full()

size = abs(int(input("Введите размер тензора (матрица квадратная): ")))

a = torch.torch.full((size, size), 5,dtype= torch.float16, device='cuda')
print(a)
#87100
torch.cuda.empty_cache()
gc.collect()
# Out:
# Введите размер тензора (матрица квадратная): 0
# tensor([], device='cuda:0', size=(0, 0), dtype=torch.float16)
# 52

# %%
torch.cuda.empty_cache()
